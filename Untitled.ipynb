# %% [markdown]
# # Independent Lab: Decision Trees
#
# **Intro to Python**
# **Decision Treesn**
# **Cody Thompson**
# **Date:** 5/05/2025
#
# Welcome to my notebook for the Decision Trees lab! In this notebook, I will be working with the hospital dataset to implement and assess classification and regression trees. The goal is to predict various target variables like Operating Income, Operating Revenue, TypeControl, and DonorType using different sets of predictor variables. I will also assess each tree's performance and interpret the results to justify the best model selection.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# for pca
from sklearn import preprocessing
from sklearn.decomposition import PCA as pca

# for factor analysis
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

# for k-means clustering 
import sklearn.metrics as metcs
from scipy.cluster import hierarchy as hier
from sklearn import cluster as cls

# for decision tree 
from sklearn.feature_extraction.image import grid_to_graph
from sklearn import tree

# modules for plotting trees
from sklearn.tree import export_graphviz
import graphviz
from IPython.display import display

# %%
# set working directory
os.chdir("C://Users//cthom//Downloads//BGEN 632 Intro to Python//GitHub_Repos//Week 10//week10labs//data")  # change this to your filepath
os.getcwd()  # confirm change
# Out:
# 'C:\\Users\\cthom\\Downloads\\BGEN 632 Intro to Python\\GitHub_Repos\\Week 10\\week10labs\\data'

# %%
# Load the dataset
hospital_data = pd.read_csv('calihospital.txt', delimiter='\t')

# Display the first few rows of the dataset
hospital_data.head()
# Out:
#    HospitalID                              Name         Zip  \
# 0       45740                  Mammoth Hospital  93546-0660
# 1       12145  Victor Valley Community Hospital       92392
# 2       25667        Pioneers Memorial Hospital       92227
# 3       46996      Ridgecrest Regional Hospital       93555
# 4       37393        Barstow Community Hospital       92311
#
#                    Website TypeControl     Teaching DonorType  NoFTE  \
# 0  www.mammothhospital.com    District  Small/Rural   Charity  327.0
# 1             www.vvch.org  Non Profit  Small/Rural   Charity  345.0
# 2             www.pmhd.org    District  Small/Rural   Charity  601.2
# 3              www.rrh.org  Non Profit  Small/Rural   Charity  400.0
# 4  www.barstowhospital.com    Investor  Small/Rural   Charity  262.0
#
#      NetPatRev    InOperExp  ...  AvlBeds  Work_ID   LastName  FirstName  \
# 0  135520.2186  20523425.53  ...       15   721586        Web      David
# ...

# %% [markdown]
# # Select Predictor and Target Variables
#
# **For each model, I’ll choose the following predictors and target variables:**
#
# * Model 1: Operating Income as the target variable
# * Predictors: TypeControl, NoFTE, AvlBeds
# * Model 2: Operating Revenue as the target variable
# * Predictors: TypeControl, NetPatRev, NoFTE
# * Model 3: TypeControl as the target variable
# * Predictors: NoFTE, NetPatRev, AvlBeds
# * Model 4: DonorType as the target variable
# * Predictors: NoFTE, NetPatRev, AvlBeds

# %%
# Selecting features for Classification and Regression Trees
# Regression Trees: Predicting Operating Income and Operating Revenue
numerical_features = ['NoFTE', 'NetPatRev', 'InOperExp', 'OutOperExp', 'OperRev', 'OperInc', 'AvlBeds']

# Classification Trees: Predicting TypeControl and DonorType
categorical_features = ['TypeControl', 'DonorType']
target1 = 'OperInc'  # Operating Income (Regression)
target2 = 'OperRev'  # Operating Revenue (Regression)
target3 = 'TypeControl'  # TypeControl (Classification)
target4 = 'DonorType'  # DonorType (Classification)

# %%
# Splitting the data for both regression and classification tasks
X = hospital_data[numerical_features]  # Predictors
y1 = hospital_data[target1]  # Target for Operating Income (Regression)
y2 = hospital_data[target2]  # Target for Operating Revenue (Regression)
y3 = hospital_data[target3]  # Target for TypeControl (Classification)
y4 = hospital_data[target4]  # Target for DonorType (Classification)

# Splitting the data for regression and classification models
X_train, X_test, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=42)
X_train, X_test, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=42)
X_train, X_test, y_train3, y_test3 = train_test_split(X, y3, test_size=0.2, random_state=42)
X_train, X_test, y_train4, y_test4 = train_test_split(X, y4, test_size=0.2, random_state=42)

# %%
# Ensure both X_train and X_test have the same features
X_train1 = X_train[['NoFTE', 'NetPatRev', 'InOperExp', 'OutOperExp', 'OperRev', 'OperInc', 'AvlBeds']]
X_test1 = X_test[['NoFTE', 'NetPatRev', 'InOperExp', 'OutOperExp', 'OperRev', 'OperInc', 'AvlBeds']]

X_train2 = X_train[['NoFTE', 'NetPatRev', 'InOperExp', 'OutOperExp', 'OperRev', 'OperInc', 'AvlBeds']]
X_test2 = X_test[['NoFTE', 'NetPatRev', 'InOperExp', 'OutOperExp', 'OperRev', 'OperInc', 'AvlBeds']]

X_train3 = X_train[['NoFTE', 'NetPatRev', 'AvlBeds']]
X_test3 = X_test[['NoFTE', 'NetPatRev', 'AvlBeds']]

X_train4 = X_train[['NoFTE', 'NetPatRev', 'AvlBeds']]
X_test4 = X_test[['NoFTE', 'NetPatRev', 'AvlBeds']]

# %% [markdown]
# # Build the Regression Trees

# %%
# Model 1: Predicting Operating Income (Regression)
regressor1 = DecisionTreeRegressor(random_state=42)
regressor1.fit(X_train1, y_train1)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Model 2: Predicting Operating Revenue (Regression)
regressor2 = DecisionTreeRegressor(random_state=42)
regressor2.fit(X_train2, y_train2)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# # Build the Classification Trees

# %%
# Model 3: Predicting TypeControl (Classification)
classifier3 = DecisionTreeClassifier(random_state=42)
classifier3.fit(X_train3, y_train3)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Model 4: Predicting DonorType (Classification)
classifier4 = DecisionTreeClassifier(random_state=42)
classifier4.fit(X_train4, y_train4)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# # Visualize the Regression Tree for Operating Income

# %%
# Visualize the Regression Tree for Operating Income
plt.figure(figsize=(12, 8))  # Adjust the figure size
tree.plot_tree(regressor1, 
               filled=True, 
               feature_names=numerical_features, 
               fontsize=8,   # Reduce font size
               rounded=True) # Make tree nodes rounded
plt.title("Decision Tree for Operating Income")
plt.show()

# %% [markdown]
# # Using graphviz for better visualization:

# %%
# Using graphviz for better visualization:
dot_data1 = export_graphviz(regressor1, 
                            filled=True, 
                            feature_names=numerical_features, 
                            rounded=True, 
                            special_characters=True)
graph1 = graphviz.Source(dot_data1)
graph1.render("decision_tree_operating_income", format="png", cleanup=True)  # Save as PNG or another format
graph1.view()  # Display the graph
# Out:
# 'decision_tree_operating_income.pdf'

# %% [markdown]
# # Visualize the Regression Tree for Operating Revenue

# %%
# Visualize the Regression Tree for Operating Revenue 
plt.figure(figsize=(12, 8))  # Adjust the figure size
tree.plot_tree(regressor2, 
               filled=True, 
               feature_names=numerical_features, 
               fontsize=8,   # Reduce font size
               rounded=True) # Make tree nodes rounded
plt.title("Decision Tree for Operating Revenue")
plt.show()

# %% [markdown]
# # Using graphviz for better visualization:

# %%
# Using graphviz for better visualization:
dot_data2 = export_graphviz(regressor2, 
                            filled=True, 
                            feature_names=numerical_features, 
                            rounded=True, 
                            special_characters=True)
graph2 = graphviz.Source(dot_data2)
graph2.render("decision_tree_operating_revenue", format="png", cleanup=True)  # Save as PNG or another format
graph2.view()  # Display the graph
# Out:
# 'decision_tree_operating_revenue.pdf'

# %% [markdown]
# # Visualize the Classification Tree for TypeControl

# %%
# Visualize the Classification Tree for TypeControl
plt.figure(figsize=(15,10))
tree.plot_tree(classifier3, filled=True, feature_names=numerical_features, fontsize=10)
plt.title("Decision Tree for TypeControl")
plt.show()

# %% [markdown]
# # Visualize the Classification Tree for DonorType

# %%
# Visualize the Classification Tree for DonorType
plt.figure(figsize=(15,10))
tree.plot_tree(classifier4, filled=True, feature_names=numerical_features, fontsize=10)
plt.title("Decision Tree for DonorType")
plt.show()

# %%
# Evaluate the regression model for Operating Income (regressor1)
y_pred1 = regressor1.predict(X_test1)
mse1 = mean_squared_error(y_test1, y_pred1)
r2_1 = r2_score(y_test1, y_pred1)

print(f"Operating Income Regression Tree:")
print(f"Mean Squared Error (MSE): {mse1}")
print(f"R-squared: {r2_1}\n")
# Out:
# Operating Income Regression Tree:
# Mean Squared Error (MSE): 16176247993784.691
# R-squared: 0.9983263943475736

# %%
# Evaluate the regression model for Operating Revenue (regressor2)
y_pred2 = regressor2.predict(X_test2)
mse2 = mean_squared_error(y_test2, y_pred2)
r2_2 = r2_score(y_test2, y_pred2)

print(f"Operating Revenue Regression Tree:")
print(f"Mean Squared Error (MSE): {mse2}")
print(f"R-squared: {r2_2}\n")
# Out:
# Operating Revenue Regression Tree:
# Mean Squared Error (MSE): 3283823519889868.5
# R-squared: 0.9853679031914157

# %%
# Evaluate the classification model for TypeControl (classifier3)
y_pred3 = classifier3.predict(X_test3)
# Classification report for TypeControl
from sklearn.metrics import classification_report
print(f"TypeControl Classification Tree:")
print(classification_report(y_test3, y_pred3))
# Out:
# TypeControl Classification Tree:
#               precision    recall  f1-score   support
#
#  City/County       1.00      0.50      0.67         2
#     District       1.00      0.25      0.40         4
#     Investor       0.00      0.00      0.00         0
#   Non Profit       0.56      0.71      0.62         7
#
#     accuracy                           0.54        13
#    macro avg       0.64      0.37      0.42        13
# weighted avg       0.76      0.54      0.56        13
# C:\Users\cthom\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# Evaluate the classification model for DonorType (classifier4)
y_pred4 = classifier4.predict(X_test4)
# Classification report for DonorType
print(f"DonorType Classification Tree:")
print(classification_report(y_test4, y_pred4))
# Out:
# DonorType Classification Tree:
#               precision    recall  f1-score   support
#
#       Alumni       1.00      1.00      1.00         4
#      Charity       1.00      1.00      1.00         9
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
